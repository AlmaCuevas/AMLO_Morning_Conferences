# %%
import pandas as pd
import spacy
import networkx as nx                        # a really useful network analysis library
import matplotlib.pyplot as plt
import pickle

# %%
# To open the network
year_label = '2023'
measures_dict = pickle.load(open(f'/Users/almacuevas/work_projects/conferencias_matutinas_amlo/measures/measures_{year_label}.pickle', 'rb'))

# %%
for measure in measures_dict.keys():
    measures_dict[measure] =
# Out:
# dict_keys(['sorted_pagerank', 'sorted_bw', 'sorted_cc', 'biggest_coefficient'])

# %%
G['sorted_pagerank']
# Out:
# [(contrapuesto, 0.0003008934478328427),
#  (consecuente, 0.000283860092864229),
#  (controvertido, 0.0002756995996694815),
#  (convencional, 0.00027150717191307285),
#  (contradictorio, 0.00027098098332379797),
#  (intencionado, 0.00026776895050254),
#  (desentendido, 0.0002677150896906324),
#  (fundamentado, 0.0002670313006094082),
#  (desconocimiento, 0.00026442075648310117),
#  (instrumentalizado, 0.00026182191177802014),
#  (contraproducente, 0.00026125785121749475),
#  (interrelacionado, 0.00026118347633496107),
#  (convencimiento, 0.0002606686161644094),
#  (sobredimensionado, 0.000260286032486724),
#  (consiguiente, 0.0002597959224212459),
#  (particularidad, 0.000259543851215552),
#  (condicionante, 0.0002586688355296974),
#  (contradicción, 0.00025819677832498934),
#  (condicionado, 0.00025725545545074403),
#  (persistente, 0.0002567381669576739),
#  (vertimiento, 0.0002563685566794194),
#  (incipiente, 0.00025613320224406337),
#  (evidente, 0.00025583675536606994),
# ...

# %%
G['sorted_bw']
# Out:
# [(cado, 0.006164743463921621),
#  (condimento, 0.0024077444789216643),
#  (serpiente, 0.0023015352185415754),
#  (recipiente, 0.00225194304115921),
#  (ran, 0.002148165049253115),
#  (pasado, 0.0019456025015848098),
#  (habitación, 0.0019347403431831704),
#  (pegamento, 0.0018748443142412449),
#  (venado, 0.0017828438446200585),
#  (carrillo, 0.0017670713828706096),
#  (muchacho, 0.001761457421575645),
#  (lugarteniente, 0.001711208916869641),
#  (compadre, 0.0016951793147248087),
#  (papi, 0.0016842625057898696),
#  (ingrediente, 0.0016754361099197478),
#  (ka, 0.0016129197516350736),
#  (circundante, 0.0015180109891601533),
#  (estante, 0.0014973452830475032),
#  (porfirista, 0.001484041523046018),
#  (chingado, 0.0014629709669899493),
#  (contrincante, 0.0014352403687333403),
#  (franquista, 0.0013985254016881253),
#  (sobrecito, 0.0013933468227246032),
#  (aviente, 0.0013787697891922785),
#  (caminante, 0.0013615643307356181),
#  (ro, 0.0013543216781198917),
# ...

# %%
G['sorted_cc']
# Out:
# [(contrapuesto, 0.5717309124480399),
#  (consecuente, 0.5621619730469491),
#  (incipiente, 0.5583927125158422),
#  (desentendido, 0.5576244583825941),
#  (controvertido, 0.5569093260217315),
#  (intencionado, 0.556628882761054),
#  (contradictorio, 0.5563741793279245),
#  (convencional, 0.5557892450990751),
#  (sobredimensionado, 0.555713039992343),
#  (desplante, 0.5556368557799417),
#  (miente, 0.5552055394991993),
#  (consiguiente, 0.5549014838915874),
#  (fundamentado, 0.5529080676200475),
#  (consciente, 0.5526567571943304),
#  (condicionante, 0.5517789669192442),
#  (condicionado, 0.5517539281677389),
#  (contente, 0.551703857481395),
#  (autosuficiente, 0.5510787398038645),
#  (persistente, 0.5508540440824747),
#  (contrario, 0.5507043487038572),
#  (desconocimiento, 0.5506794073837167),
#  (contingente, 0.5506295315203543),
#  (contrapartida, 0.550554734663005),
#  (vertimiento, 0.5504550371240194),
#  (instrumentado, 0.5503802876621612),
# ...

# %%
G['biggest_coefficient']
# Out:
# [(lid, 1.0),
#  (rav, 1.0),
#  (cctv, 1.0),
#  (errata, 1.0),
#  (by, 1.0),
#  (cámbiale, 1.0),
#  (spin, 1.0),
#  (pirotecnia, 1.0),
#  (cabo, 1.0),
#  (claudio, 1.0),
#  (tok, 1.0),
#  (camín, 1.0),
#  (rifan, 1.0),
#  (bic, 1.0),
#  (may, 1.0),
#  (pick, 1.0),
#  (mem, 1.0),
#  (creces, 1.0),
#  (dhl, 1.0),
#  (discúlpeme, 1.0),
#  (cannábico, 1.0),
#  (oprima, 1.0),
#  (hico, 1.0),
#  (rasero, 1.0),
#  (ámpula, 1.0),
#  (topic, 1.0),
#  (cieno, 1.0),
#  (apágalo, 1.0),
#  (lelo, 1.0),
#  (malasio, 1.0),
#  (lula, 1.0),
#  (íntegro, 1.0),
#  (oca, 1.0),
#  (dadiva, 1.0),
#  (score, 1.0),
#  (sincitial, 1.0),
#  (aquilata, 1.0),
#  (tope, 1.0),
#  (cuánta, 1.0),
#  (corso, 1.0),
#  (xx, 1.0),
#  (bajío, 1.0),
#  (redotex, 1.0),
#  (om, 1.0),
#  (bruto, 0.9722222222222222),
#  (onceavo, 0.9615384615384616),
#  (encuadró, 0.9601449275362319),
#  (conexas, 0.9566736547868623),
#  (marcos, 0.9566273421235253),
#  (siéntense, 0.9523809523809523),
#  (abreviado, 0.9502127877762395),
# ...
